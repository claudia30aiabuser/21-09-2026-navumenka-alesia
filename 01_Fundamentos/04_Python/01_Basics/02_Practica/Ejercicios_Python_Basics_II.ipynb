# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
a=50
b=23.4
print(type(a), type(b))
c=a+b
print(c, type(c))
del a, b
#print(a,b, c)
# Out:
# <class 'int'> <class 'float'>
# 73.4 <class 'float'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3 print(type(a), type(b))
#       4 c=a+b
#       5 print(c, type(c))
#       6 del a, b
# ----> 7 print(a,b, c)
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
print("angulo en grados:")
gr=float(input("angulo en grados:"))
print(gr)
import math
print("angulo en radianes: ", round(gr*math.pi/180, 2))
# Out:
# angulo en grados:
# 128.0
# angulo en radianes:  2.23

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
print("Introduce la longitud de la base:")
b=float(input("Introduce la longitud de la base:"))
print(b)
print("Introduce la longitud de la altura:")
a=float(input("Introduce la longitud de la altura:"))
print(a)
print("Area: ", round(a*b, 2))
# Out:
# Introduce la longitud de la base:
# 56.0
# Introduce la longitud de la altura:
# 0.999445257527
# Area:  55.97

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print("1  ", A==B)
print("2  ", A!=C)
print("3  ", A>C)
print("4  ", C<=A)
print("5  ", B!=C)
# Out:
# 1   False
# 2   True
# 3   False
# 4   False
# 5   True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
a1=input("lo primero: ")
print("lo primero: ", a1)
a2=input("lo segundo: ")
print("lo segundo: ", a2)

if a1==a2: print("es lo mismo")
else: print("no es lo mismo")
# Out:
# lo primero:  jgg
# lo segundo:  kislf
# no es lo mismo

# %%
a1=input("lo primero: ")
print("lo primero: ", a1)
a2=input("lo segundo: ")
print("lo segundo: ", a2)

print("es lo mismo: ", a1==a2)
# Out:
# lo primero:  5
# lo segundo:  2
# es lo mismo:  False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
b1=input("lo primero: ")
print("lo primero: ", b1)
b2=input("lo segundo: ")
print("lo segundo: ", b2)
b3=input("lo tercero: ")
print("lo tercero: ", b3)

if b1!=b2 and b2!=b3 and b1!=b3: None
elif b1==b2 and b2==b3 and b1==b3: print("todo es lo mismo")
else: print("por lo menos dos son iguales")
# Out:
# lo primero:  5
# lo segundo:  5
# lo tercero:  78
# por lo menos dos son iguales

# %%
b1=input("lo primero: ")
print("lo primero: ", b1)
b2=input("lo segundo: ")
print("lo segundo: ", b2)
b3=input("lo tercero: ")
print("lo tercero: ", b3)

print("todo es igual: ", b1==b2==b3)
print("al menos dos son iguales: ", (not b1==b2==b3) and (not b1!=b2!=b3))
# Out:
# lo primero:  1
# lo segundo:  1
# lo tercero:  9
# todo es igual:  False
# al menos dos son iguales:  True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
c1=float(input("lo primero: "))
print("lo primero: ", c1)
c2=float(input("lo segundo: "))
print("lo segundo: ", c2)


print("suma es mayor que 10:", (c1+c2) > 10)
print("suma es igual que 10:", (c1+c2) == 10)
# Out:
# lo primero:  4.0
# lo segundo:  6.0
# suma es mayor que 10: False
# suma es igual que 10: True

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1 False
# 2 False
# 3 False
# 4 False

# %%
print(True and True and False)
print(not ((True or False) and (True or False)))
print((False or False or False or True) and False)
print(not False and True and not True)
# Out:
# False
# False
# False
# False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
max([4, 6, 8, -1])
sum([4, 6, 8, -1])
round(63.451256965, 3)
import math
math.fabs(-74)
# Out:
# 74.0

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
"En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".upper()
# Out:
# 'en un lugar de la mancha, de cuyo nombre no quiero acordarme.'

# %%
"En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".lower()
# Out:
# 'en un lugar de la mancha, de cuyo nombre no quiero acordarme.'

# %%
"En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".title()
# Out:
# 'En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.'

# %%
"En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".split()
# Out:
# ['En',
#  'un',
#  'lugar',
#  'de',
#  'la',
#  'Mancha,',
#  'de',
#  'cuyo',
#  'nombre',
#  'no',
#  'quiero',
#  'acordarme.']

# %%
"En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".replace(",", ";")
# Out:
# 'En un lugar de la Mancha; de cuyo nombre no quiero acordarme.'

# %%
"En un lugar de la Mancha, de cuyo nombre no quiero acordarme.".replace("a", "")
# Out:
# 'En un lugr de l Mnch, de cuyo nombre no quiero cordrme.'

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
#1
ej11list=[54, 154.225, -11]

#2
ej11list.append(0)
ej11list

#3
#sum(ej11list)

#4
#ej11list.pop(1)
#ej11list

#5
#ej11list.insert(2, 2026)
#ej11list

#6
#ej22list=[0,1,2,10]
#ej11list+ej22list
# Out:
# [54, 154.225, 2026, -11, 0, 0, 1, 2, 10]
