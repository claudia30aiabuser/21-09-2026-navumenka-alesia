# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("¿Por que esta magnifica tecnologia cientifica, \n\tque ahorra trabajo  y nos hace la vida mas facil, \n\t\tnos aporta tan poca felicidad?\n\t\t\tLa respuesta es esta, simplemente: porque aun no hemos aprendido a usarla con tino.\n""Albert Einstein""")
# Out:
# ¿Por que esta magnifica tecnologia cientifica,
# 	que ahorra trabajo  y nos hace la vida mas facil,
# 		nos aporta tan poca felicidad?
# 			La respuesta es esta, simplemente: porque aun no hemos aprendido a usarla con tino.
# Albert Einstein

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
calle="Ruben Dario"
numero="5"
pobla="Valencia"
postal=46021
print("Vivo en " + calle +" "+ numero + ", " + str(postal) + " "+ pobla)
# Out:
# Vivo en Ruben Dario 5, 46021 Valencia

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
# Out:
# Castellana 24 Madrid 26774

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %%
mi_variable10 = 6

# %%
81mi_variable = "Agua"
# Out:
#   Cell In[14], line 1
#     81mi_variable = "Agua"
#      ^
# SyntaxError: invalid decimal literal

# %%
import = 40
# Out:
#   Cell In[13], line 1
#     import = 40
#            ^
# SyntaxError: invalid syntax

# %%
exec = True

# %%
mi variab1e = "Alpha"
# Out:
#   Cell In[10], line 1
#     mi variab1e = "Alpha"
#        ^
# SyntaxError: invalid syntax

# %%
True = "Ejercicio"
# Out:
#   Cell In[9], line 1
#     True = "Ejercicio"
#     ^
# SyntaxError: cannot assign to True

# %%
otra_var = "Ejercicio
# Out:
#   Cell In[8], line 1
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
print("temp en Celsius:")
cels=float(input())
print(cels)

print("En Fahrenheit seria:", cels*9/5+32)
# Out:
# temp en Celsius:
# 1452.0
# En Fahrenheit seria: 2645.6

# %%
cels=float
print("temp en Celsius:", input(cels))

#print(cels)
print("En Fahrenheit seria:", cels*9/5+32)
# Out:
# temp en Celsius: 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 cels=float
#       2 print("temp en Celsius:", input(cels))
#       3
#       4 #print(cels)
# ----> 5 print("En Fahrenheit seria:", cels*9/5+32)
#
# TypeError: unsupported operand type(s) for *: 'type' and 'int'

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
print("temp en Celsius:") 
cels=float(input()) #no olvidar guardar lo tecleado en alguna variable
print(cels) #tambien hay que mostrarlo

print("En Fahrenheit seria:", cels*9/5+32)
# Out:
# El equivalente en grados Fahrenheit es 41.0

# %%
print("temp en Celsius:") 
cels=float(input("temp en Celsius:")) 
print(cels) 

print("En Fahrenheit seria:", cels*9/5+32)
# Out:
# temp en Celsius:
# 658.0
# En Fahrenheit seria: 1216.4
