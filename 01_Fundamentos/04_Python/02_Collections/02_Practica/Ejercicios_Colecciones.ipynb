# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]
ejer_1.reverse()
print(ejer_1)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Ejercicio 2
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]

for i in range(len(ejer_2)):
    ejer_2[i]=(ejer_2[i])**2

print(ejer_2)
# Out:
# [1, 4, 9, 16, 25]

# %%
ejer2 = [1,2,3,4,5]
pows=[]
for i in range(len(ejer2)): pows.append(2)

print(pows)

import math
ejer22=list(map(math.pow, ejer2, pows))

print(ejer22)
# Out:
# [2, 2, 2, 2, 2]
# [1.0, 4.0, 9.0, 16.0, 25.0]

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]

resultlist=[]
resultlist.append(ejer_3_1[0]+" "+ejer_3_2[0])
resultlist.append(ejer_3_1[0]+" "+ejer_3_2[1])
resultlist.append(ejer_3_1[1]+" "+ejer_3_2[1])
resultlist.append(ejer_3_1[1]+" "+ejer_3_2[0])

print(resultlist)
# Out:
# ['Hola Que', 'Hola tal', 'amigo tal', 'amigo Que']

# %%
ejer31 = ["Hola", "amigo"]
ejer32 = ["Que", "tal"]

zip()???

# %%
ejer_31 = ["Hola", "amigo", "viernes"]
ejer_32 = ["Que", "tal", "44"]
resultlist=[]
print(type(resultlist))

for x in ejer_31: 
    for y in ejer_32:
        resultlist.append(x + " " + y)

print(resultlist)
# Out:
# <class 'list'>
# ['Hola Que', 'Hola tal', 'Hola 44', 'amigo Que', 'amigo tal', 'amigo 44', 'viernes Que', 'viernes tal', 'viernes 44']

# %%
ejer_31 = ["Hola", "amigo", "viernes"]
ejer_32 = ["Que", "tal", "44"]

combinaciones = [(x, y) for x in ejer_31 for y in ejer_32]

print(combinaciones)
# Out:
# [('Hola', 'Que'), ('Hola', 'tal'), ('Hola', '44'), ('amigo', 'Que'), ('amigo', 'tal'), ('amigo', '44'), ('viernes', 'Que'), ('viernes', 'tal'), ('viernes', '44')]

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra el índice del valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]

a=ejer_4.index(45)
ejer_4[a]=0

print(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# Consejo: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]

test5=[]

for i in range(len(ejer_5)): 
    if (ejer_5[i]) != 3:
        test5.append(ejer_5[i])

print(test5)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y ultimo elemento de la tupla del apartado 3. Usa `len` para el ultimo
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
tp_solt=(55,)
print(type(tp_solt))

tp6=(True, 44, "V", )

print(tp6[0], tp6[len(tp6)-1])

task5tp=tp6 + (45,)
print(task5tp)

task61=task5tp[0:(len(task5tp)//2)] + task5tp[(len(task5tp)//2+1):len(task5tp)]
print(task61)

print(list(task5tp))
# Out:
# <class 'tuple'>
# True V
# (True, 44, 'V', 45)
# (True, 44, 45)
# [True, 44, 'V', 45]

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un unico string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")
str7=" "

str7=" ".join(ejer_7)   

print(str7)
# Out:
# cien cañones por banda

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)

print(ejer_8[2], ejer_8[-3])
# Out:
# 3 90

# %% [markdown]
# ## Ejercicio 9
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_9`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

print(ejer_9.count(3))

newej9=ejer_9[4:10]
print(newej9)

print(len(ejer_9))
# Out:
# 7
# (19, 3, 29, 45, 67, 78)
# 26

# %% [markdown]
# ## Ejercicio 10
# Comprueba si el numero 60 esta en la tupla del ejercicio 9

# %%
ejer_9.index(60)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 ejer_9.index(60)
#
# ValueError: tuple.index(x): x not in tuple

# %%
60 in ejer_9
# Out:
# False

# %% [markdown]
# ## Ejercicio 11
# 1. Convierte la tupla del apartado 10 en una lista
# 2. Convierte la tupla del apartado 10 en un set
# 3. Convierte la tupla del apartado 10 en un diccionario. Usa también los indices

# %%
print(list(ejer_9))
print(set(ejer_9))
dict11={}

for k, v in enumerate(ejer_9):
    dict11[k]=v

print(dict11)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 12
# Convierte la siguiente tupla en un diccionario
# > ```ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %% [markdown]
# resultado:
# x: ,,,   y:,,,,    z:,,,,

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]

dic12=dict(ejer_12)
print(dic12)
# Out:
# {'x': 3, 'y': 2, 'z': 1}

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
dict12={}
print(type(dict12))

for i, v in enumerate(ejer_12):
    dict12[i]=v

print(dict12)
# Out:
# <class 'dict'>
# {0: ('x', 1), 1: ('x', 2), 2: ('x', 3), 3: ('y', 1), 4: ('y', 2), 5: ('z', 1)}

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
dictv2={}

v2keys=set()

for a, b in ejer_12: 
    v2keys.add(a)

print(v2keys)

for k in v2keys: 
    vals=[]
    for x,y in ejer_12:
      
        if k==x: 
            vals.append(y)
            dictv2[k]=vals
        else: pass

print(dictv2)
# Out:
# {'z', 'x', 'y'}
# {'z': [1], 'x': [1, 2, 3], 'y': [1, 2]}

# %%
ejer_12 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
dictv2={}

for i,j in ejer_12: 
    if i not in dictv2.keys(): 
        dictv2[i]=[j]
    else: 
        dictv2[i].append(j)

print(dictv2)
# Out:
# {'x': [1, 2, 3], 'y': [1, 2], 'z': [1]}

# %% [markdown]
# ## Ejercicio 13
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un unico for
# > ```ejer_13 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_13 = {4:78, 2:98, 8:234, 5:29}

claves1=list(ejer_13.keys())
claves1.sort()
print(claves1)

valores1=list(ejer_13.values())
valores1.sort(reverse=True)
#valores1.reverse()
print(valores1)

ejer_13[10]=50
print(ejer_13)

print(ejer_13[2])

for i in ejer_13.keys(): print(i, ejer_13[i])
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]
# {4: 78, 2: 98, 8: 234, 5: 29, 10: 50}
# 98
# 4 78
# 2 98
# 8 234
# 5 29
# 10 50

# %% [markdown]
# ## Ejercicio 14
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_14_1 = {1: 11, 2: 22}```
# >
# > ```ejer_14_2 = {3: 33, 4: 44}```

# %%
ejer_14_1 = {1: 11, 2: 22}
ejer_14_2 = {3: 33, 4: 44}

ejer_14_1.update(ejer_14_2)
print(ejer_14_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44}

# %% [markdown]
# ## Ejercicio 15
# Suma todos los valores del dicionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

a=0
for i in ejer_15: a=a+ejer_15[i]

print(a)
# Out:
# 165

# %% [markdown]
# ## Ejercicio 16
# Multiplica todos los valores del diccionario
# > ```ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_16 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

q=1
for i in ejer_16: q=q*ejer_16[i]

print(q)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 17
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el utlimo elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
set17={40,50,60}
print(set17)

set17.add(80)
print(set17)

set17.remove(80)
print(set17)

set17.discard(10)
print(set17)
# Out:
# {40, 50, 60}
# {40, 50, 80, 60}
# {40, 50, 60}
# {40, 50, 60}
